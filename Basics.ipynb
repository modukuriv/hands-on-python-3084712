# %% [markdown]
# <a href="https://colab.research.google.com/github/modukuriv/hands-on-python-3084712/blob/main/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Learn Python")
# Out:
# Learn Python

# %% [markdown]
# ```
# # Data Types and Variables
# #Create a variable
# ```

# %%
greeting = "Hello"
print(greeting)
# Out:
# Hello

# %%
number = 20
print(number)
print(type(number))
# Out:
# 20
# <class 'int'>

# %%
pi = 3.14
print(pi)
print(type(pi))
# Out:
# 3.14
# <class 'float'>

# %%
name = "Sri Rama"
print(name)
print(type(name))
# Out:
# Sri Rama
# <class 'str'>
